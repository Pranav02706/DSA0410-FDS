# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranav02706/DSA0410-FDS/blob/main/House.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
f=pd.read_csv('/content/House_Prediction - House_Prediction.csv')
avg=f[f['beds']>=4]['price'].mean()
print("Average sales of 4BHK house is:", avg)
# Out:
# Average sales of 4BHK house is: 1352618.972972973
