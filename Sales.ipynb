# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranav02706/DSA0410-FDS/blob/main/Sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
f=pd.read_csv('/content/Sales - Sales.csv')
avg=f[f['Month_sales']=='November 2023']['Price'].mean()
print("Average Sales =",avg)
# Out:
# Average Sales = 2337.3635789473683
