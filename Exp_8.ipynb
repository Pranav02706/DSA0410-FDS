# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranav02706/DSA0410-FDS/blob/main/Exp_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
f=pd.read_csv("/content/Sales - Sales.csv")
top_5_products=f.groupby("Product_Name")["Price"].sum().nlargest(5)
print("Five most sold products: ", top_5_products)
# Out:
# Five most sold products:  Product_Name
# Clothing       729296.71
# Furniture      710856.99
# Electronics    687620.97
# Food           600665.45
# Name: Price, dtype: float64
